# %% [markdown]
# ### TỔNG QUAN VỀ ĐỀ TÀI

# %% [markdown]
# <b><u>Đề tài:</u> Phân tích điểm thi THPT quốc gia năm 2020, 2022</b><br>
# <b><u>Lí do chọn đề tài:</u></b>
# <ol>Điểm thi THPT quốc gia tuy không nói lên nhiều về năng lực của đa số học sinh hay nói về trình độ chuyên môn giảng dạy của một hệ thống tỉnh thành nào đó, tuy nhiên qua đó chúng ta có thể nhìn nhận nhiều khía cạnh để nâng cao chất lượng giảng dạy của hệ thống giáo dục Việt Nam. Và hơn hết, cũng là người từng đi thi nên muốn khám phá xem mình đã trải nghiệm một kì thi như thế nào</ol>
# <b><u>Dữ liệu:</u></b> Điểm thi THPT Quốc Gia hai năm 2020 và 2022

# %% [markdown]
# ## THƯ VIỆN SỬ DỤNG

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## A. THU THẬP DỮ LIỆU

# %% [markdown]
# <ul> <h2>I. Lí do chọn dữ liệu:</h2>
# <ol> Chọn 2 năm thi để có cái nhìn đánh giá tổng quan hơn về điểm số và không chọn năm 2021 vì có chia ra hai lần thi nên không đánh giá được một cách chính xác nhất mà mình đang muốn tìm hiểu khách quan nhất về điểm thi nên sẽ chọn năm 2020 và 2022, là những năm gần đây nhất</ol>
# <ol>Dữ liệu này chọn sẽ không ảnh hướng tới bất kì một ai vì đã được công bố công khai nên mình nghĩ là thế và mình sẽ che những thông tin cá nhân một cách ổn thỏa nhất và không ảnh hưởng tới một ai</ol> </ul>

# %% [markdown]
# <ul><h2> II. Thu thập dữ liệu</h2>
#     <ol> Dữ liệu có hai bộ chính là 2020 và 2022 </ol></ul>

# %% [markdown]
# ## B. CHUẨN BỊ DỮ LIỆU

# %% [markdown]
# ### <ul>I. Xử lý bộ dữ liệu năm 2020 </ul>
# <ul><ul>Dữ liệu 2020 gồm 870486 dòng và 15 cột, mỗi dòng là thông tin của một thí sinh thi, mỗi cột thì thể hiện như sau:
# <ul>Unnamed:0.2, Unnamed:0.1, Unamed:0 thứ tự thí sinh trong kì thi năm 2020</ul>
# <ul>sbd là số báo danh thi trong kì thi năm 2020 của thí sinh</ul>
# <ul>Tỉnh Thành là tỉnh thành mà thí sinh đến dự thi</ul>
# <ul>toan, van, hoa, sinh, su, dia, GDCD,Ngoai_ngu lần lượt là tên các cột chứa thông tin điểm số các môn Toán, Ngữ văn, Hóa học, Sinh học, Lịch sử, Địa lý, GDCD, Ngoại ngữ</ul>
#         <ul>Ma_mon_ngoai_ngu là cột thể hiện việc thí sinh đó thi môn ngoại ngữ là gì: tiếng Anh, tiếng Trung,...</ul>

# %%
diem2020_df = pd.read_csv('./dataset/diemthi2020.csv')
diem2020_df
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   Dia  GDCD  Hoa   Li  \
# 0                  0             0           0  7.00  6.50  NaN  NaN
# 1                  1             1           1  7.75  7.75  NaN  NaN
# 2                  2             2           2  6.50   NaN  NaN  NaN
# 3                  3             3           3  8.00  9.50  NaN  NaN
# 4                  4             4           4   NaN   NaN  8.5  8.0
# ...              ...           ...         ...   ...   ...  ...  ...
# 870481        870481        870481      870481  6.75  6.25  NaN  NaN
# 870482        870482        870482      870482  7.50  9.50  NaN  NaN
# 870483        870483        870483      870483  6.50  8.50  NaN  NaN
# 870484        870484        870484      870484  7.50  9.00  NaN  NaN
# 870485        870485        870485      870485  6.50  8.25  NaN  NaN
#
#        Ma_mon_ngoai_ngu  Ngoai_ngu  Sinh    Su  Toan   Van       sbd  \
# ...

# %% [markdown]
# #### <ul><ul>Xóa cột Unnamed:0.2, Unnamed:0.1, Unnamed:0 và Ma_mon_ngoai_ngu</ul></ul>
# <ul><ul><ul>  Có lẽ sẽ có nhiều môn được xem là ngoại ngữ như tiếng Anh, Pháp,... nhưng ở đây mình xem xét chung là 1 môn và gọi là ngoại ngữ  </ul></ul></ul></ul></ul>

# %%
diem2020_df = diem2020_df.drop(diem2020_df.columns[[0,1,2,7]],axis=1)
diem2020_df
# Out:
#          Dia  GDCD  Hoa   Li  Ngoai_ngu  Sinh    Su  Toan   Van       sbd  \
# 0       7.00  6.50  NaN  NaN        4.2   NaN  4.75   6.4  6.75  18014547
# 1       7.75  7.75  NaN  NaN        2.8   NaN  3.75   7.6  6.00  18014530
# 2       6.50   NaN  NaN  NaN        NaN   NaN  4.00   4.8  4.75  18014521
# 3       8.00  9.50  NaN  NaN        5.8   NaN  8.25   8.0  7.00  18014517
# 4        NaN   NaN  8.5  8.0        4.0   5.0   NaN   8.2  6.50  18014523
# ...      ...   ...  ...  ...        ...   ...   ...   ...   ...       ...
# 870481  6.75  6.25  NaN  NaN        2.0   NaN  3.75   4.6  4.00  17014593
# 870482  7.50  9.50  NaN  NaN        2.6   NaN  5.50   7.4  8.00  17014597
# 870483  6.50  8.50  NaN  NaN        6.2   NaN  4.50   8.2  8.75  17014595
# 870484  7.50  9.00  NaN  NaN        3.6   NaN  4.50   4.6  6.50  17014598
# 870485  6.50  8.25  NaN  NaN        3.4   NaN  4.25   8.0  7.75  60005601
#
#         Tỉnh Thành
# 0        Bắc Giang
# 1        Bắc Giang
# ...

# %% [markdown]
# #### <ul><ul>Thay đổi tên cột Dia: Địa lí, Hoa: Hóa học, Li: Vật lí, Ngoai_ngu: Ngoại ngữ, Sinh: Sinh học, Su: Lịch sử, Toan: Toán, Van: Ngữ văn, sbd: SBD và thêm hai cột KHTN và KHXH</ul></ul>

# %%
diem2020_df=diem2020_df.rename(columns={'Dia': 'Địa lí', 'Hoa': 'Hóa học', 'Li': 'Vật lí', 'Ngoai_ngu': 'Ngoại ngữ', 'Sinh': 'Sinh học', 'Su': 'Lịch sử', 'Toan': 'Toán', 'Van': 'Ngữ văn', 'sbd': 'SBD'})
diem2020_df['KHTN']=round((diem2020_df['Hóa học'] + diem2020_df['Vật lí'] + diem2020_df['Sinh học'])/3,2)
diem2020_df['KHXH']=round((diem2020_df['Địa lí'] + diem2020_df['Lịch sử'] + diem2020_df['GDCD'])/3,2)
diem2020_df
# Out:
#         Địa lí  GDCD  Hóa học  Vật lí  Ngoại ngữ  Sinh học  Lịch sử  Toán  \
# 0         7.00  6.50      NaN     NaN        4.2       NaN     4.75   6.4
# 1         7.75  7.75      NaN     NaN        2.8       NaN     3.75   7.6
# 2         6.50   NaN      NaN     NaN        NaN       NaN     4.00   4.8
# 3         8.00  9.50      NaN     NaN        5.8       NaN     8.25   8.0
# 4          NaN   NaN      8.5     8.0        4.0       5.0      NaN   8.2
# ...        ...   ...      ...     ...        ...       ...      ...   ...
# 870481    6.75  6.25      NaN     NaN        2.0       NaN     3.75   4.6
# 870482    7.50  9.50      NaN     NaN        2.6       NaN     5.50   7.4
# 870483    6.50  8.50      NaN     NaN        6.2       NaN     4.50   8.2
# 870484    7.50  9.00      NaN     NaN        3.6       NaN     4.50   4.6
# 870485    6.50  8.25      NaN     NaN        3.4       NaN     4.25   8.0
#
#         Ngữ văn       SBD  Tỉnh Thành  KHTN  KHXH
# ...

# %% [markdown]
# <ul>
#     <strong>
#         Sắp xếp lại thứ tự các cột cho hợp lý
#     </strong>
# </ul>

# %%
diem2020_df = pd.DataFrame({'SBD':diem2020_df['SBD'],'Tỉnh Thành':diem2020_df['Tỉnh Thành'],'Toán':diem2020_df['Toán'],
                           'Ngữ văn':diem2020_df['Ngữ văn'],'Vật lí':diem2020_df['Vật lí'],'Hóa học':diem2020_df['Hóa học'],
                           'Sinh học':diem2020_df['Sinh học'],'KHTN':diem2020_df['KHTN'],'Lịch sử':diem2020_df['Lịch sử'],
                           'Địa lí': diem2020_df['Địa lí'],'GDCD':diem2020_df['GDCD'],'KHXH':diem2020_df['KHXH'],
                           'Ngoại ngữ':diem2020_df['Ngoại ngữ']})
diem2020_df
# Out:
#              SBD  Tỉnh Thành  Toán  Ngữ văn  Vật lí  Hóa học  Sinh học  KHTN  \
# 0       18014547   Bắc Giang   6.4     6.75     NaN      NaN       NaN   NaN
# 1       18014530   Bắc Giang   7.6     6.00     NaN      NaN       NaN   NaN
# 2       18014521   Bắc Giang   4.8     4.75     NaN      NaN       NaN   NaN
# 3       18014517   Bắc Giang   8.0     7.00     NaN      NaN       NaN   NaN
# 4       18014523   Bắc Giang   8.2     6.50     8.0      8.5       5.0  7.17
# ...          ...         ...   ...      ...     ...      ...       ...   ...
# 870481  17014593  Quảng Ninh   4.6     4.00     NaN      NaN       NaN   NaN
# 870482  17014597  Quảng Ninh   7.4     8.00     NaN      NaN       NaN   NaN
# 870483  17014595  Quảng Ninh   8.2     8.75     NaN      NaN       NaN   NaN
# 870484  17014598  Quảng Ninh   4.6     6.50     NaN      NaN       NaN   NaN
# 870485  60005601    Bạc Liêu   8.0     7.75     NaN      NaN       NaN   NaN
#
# ...

# %% [markdown]
# ### <ul>II. Xử lí bộ dữ liệu năm 2022
# <ul><ul> Dữ liệu gồm 995 441 dòng và 12 cột, mỗi dòng sẽ là thông tin điểm số của thí sinh trong kì thi năm 2019, còn dòng được quy ước như sau:
#     <ul>Unnamed:0 là cột thứ tự</ul>
#     <ul>dia_li,gdcd, hoa_hoc, vat_li, ngoai_ngu, sinh_hoc, lich_su, toan, van lần lượt là cột chứa điểm môn Địa lí,GDCD, Hóa học, Vật lí, Ngoại ngữ, Sinh học, Lịch sử, Ngữ văn của thí sinh</ul>
#     <ul>sbd là cột số báo danh của thí sinh</ul>
# </ul></ul></ul>

# %%
diem2022_df =pd.read_csv('./dataset/diemthi2022.csv')
diem2022_df
# Out:
#         Unnamed: 0       sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  \
# 0                0   1000001   3.6     5.00        4.0     NaN      NaN
# 1                1   1000002   8.4     6.75        7.6     NaN      NaN
# 2                2   1000003   5.8     7.50        5.0     NaN      NaN
# 3                3   1000004   7.4     7.50        8.6     NaN      NaN
# 4                4   1000005   7.2     8.50        9.0     NaN      NaN
# ...            ...       ...   ...      ...        ...     ...      ...
# 995436      995436  64006584   8.4     6.75        4.6     NaN      NaN
# 995437      995437  64006585   5.6     6.50        2.8     NaN      NaN
# 995438      995438  64006586   5.8     6.00        6.6     NaN      NaN
# 995439      995439  64006587   7.6     6.75        7.0     NaN      NaN
# 995440      995440  64006588   6.6     4.50        3.2     NaN      NaN
#
#         sinh_hoc  lich_su  dia_li  gdcd Tỉnh Thành
# 0            NaN     2.75    6.00  8.75     Hà Nội
# ...

# %% [markdown]
# #### <ul><ul> Xóa 2 Unnamed: 0, đổi tên cột và thêm 2 cột khtn và khxh:

# %%
diem2022_df= diem2022_df.drop(diem2022_df.columns[[0]], axis=1)
diem2022_df=diem2022_df.rename(columns={'dia_li': 'Địa lí', 'hoa_hoc': 'Hóa học','vat_li':'Vật lí','ngoai_ngu':'Ngoại ngữ','sinh_hoc':
                       'Sinh học','lich_su':'Lịch sử','toan':'Toán','ngu_van':'Ngữ văn','sbd':'SBD', 'gdcd': 'GDCD'})
diem2022_df['KHTN']=round((diem2022_df['Hóa học'] + diem2022_df['Vật lí'] + diem2022_df['Sinh học'])/3,2)
diem2022_df['KHXH']=round((diem2022_df['Địa lí'] + diem2022_df['Lịch sử'] + diem2022_df['GDCD'])/3,2)
diem2022_df
# Out:
#              SBD  Toán  Ngữ văn  Ngoại ngữ  Vật lí  Hóa học  Sinh học  \
# 0        1000001   3.6     5.00        4.0     NaN      NaN       NaN
# 1        1000002   8.4     6.75        7.6     NaN      NaN       NaN
# 2        1000003   5.8     7.50        5.0     NaN      NaN       NaN
# 3        1000004   7.4     7.50        8.6     NaN      NaN       NaN
# 4        1000005   7.2     8.50        9.0     NaN      NaN       NaN
# ...          ...   ...      ...        ...     ...      ...       ...
# 995436  64006584   8.4     6.75        4.6     NaN      NaN       NaN
# 995437  64006585   5.6     6.50        2.8     NaN      NaN       NaN
# 995438  64006586   5.8     6.00        6.6     NaN      NaN       NaN
# 995439  64006587   7.6     6.75        7.0     NaN      NaN       NaN
# 995440  64006588   6.6     4.50        3.2     NaN      NaN       NaN
#
#         Lịch sử  Địa lí  GDCD Tỉnh Thành  KHTN  KHXH
# 0          2.75    6.00  8.75     Hà Nội   NaN  5.83
# ...

# %% [markdown]
# #### <ul><ul>Làm thứ tự cột theo trình tự như năm 2020 cho dễ nhìn </ul></ul>

# %%
diem2022_df = pd.DataFrame({'SBD':diem2022_df['SBD'],'Tỉnh Thành':diem2022_df['Tỉnh Thành'],'Toán':diem2022_df['Toán'],
                           'Ngữ văn':diem2022_df['Ngữ văn'],'Vật lí':diem2022_df['Vật lí'],'Hóa học':diem2022_df['Hóa học'],
                           'Sinh học':diem2022_df['Sinh học'],'KHTN':diem2022_df['KHTN'],'Lịch sử':diem2022_df['Lịch sử'],
                           'Địa lí': diem2022_df['Địa lí'],'GDCD':diem2022_df['GDCD'],'KHXH':diem2022_df['KHXH'],
                           'Ngoại ngữ':diem2022_df['Ngoại ngữ']})
diem2022_df
# Out:
#              SBD Tỉnh Thành  Toán  Ngữ văn  Vật lí  Hóa học  Sinh học  KHTN  \
# 0        1000001     Hà Nội   3.6     5.00     NaN      NaN       NaN   NaN
# 1        1000002     Hà Nội   8.4     6.75     NaN      NaN       NaN   NaN
# 2        1000003     Hà Nội   5.8     7.50     NaN      NaN       NaN   NaN
# 3        1000004     Hà Nội   7.4     7.50     NaN      NaN       NaN   NaN
# 4        1000005     Hà Nội   7.2     8.50     NaN      NaN       NaN   NaN
# ...          ...        ...   ...      ...     ...      ...       ...   ...
# 995436  64006584  Hậu Giang   8.4     6.75     NaN      NaN       NaN   NaN
# 995437  64006585  Hậu Giang   5.6     6.50     NaN      NaN       NaN   NaN
# 995438  64006586  Hậu Giang   5.8     6.00     NaN      NaN       NaN   NaN
# 995439  64006587  Hậu Giang   7.6     6.75     NaN      NaN       NaN   NaN
# 995440  64006588  Hậu Giang   6.6     4.50     NaN      NaN       NaN   NaN
#
#         Lịch sử  Địa lí  GDCD  KHXH  Ngoại ngữ
# ...

# %% [markdown]
# ## C. PHÂN TÍCH DỮ LIỆU VÀ TÌM RA LỜI GIẢI

# %% [markdown]
# ### <ul> <u>1.</u> Một việc hết sức được cộng đồng quan tâm đó là chất lượng giáo dục trong những năm gần đây, vậy mình cùng trả lời tỉnh thành nào mạnh hay yếu về môn nào</ul>

# %% [markdown]
# <ul><ul>
#     <b>Trước khi trả lời vấn đề này thì chúng ta thử xem câu này có ý nghĩa như thế nào? </b>
#     <ul>
#         Điểm số không nói lên tất cả những cũng nói đúng phần lớn, chúng ta nên sẽ đánh giá được tỉnh nào mạnh về môn nào và yếu về môn nào rồi xem xét để cải tiến giáo dục ở từng tỉnh sao cho phù hợp và hiệu quả.
#     </ul>
# </ul>
# <ul>
#     <b>Vậy chúng ta đánh giá bằng cách nào đây?</b>
#     <ul>
#         Đánh giá thông qua hai bộ dữ liệu năm 2020 và 2022
#         <ul>
#         <li> điểm thi tốt nghiệp trung bình cao nhất, thấp nhất </li>
#         <li> 5 tỉnh thành có số thí sinh liệt cao nhất theo từng môn thi </li>
#         <li> 5 tỉnh thành có số thí sinh đạt trên 8 điểm </li>
#         </ul>
#     </ul>
# </ul></ul>

# %% [markdown]
# <ul> Vì không có điểm cộng, điểm ưu tiên, điểm học bạ năm 12 nên việc tính điểm tốt nghiệp sẽ tính bằng tổng trung bình  4 bài thi của thí sinh: Toán, Ngữ văn, Ngoại ngữ và 1 trong 2 bài KHTN và KHXH, sẽ có những thí sinh tự do, tuy nhiên việc tính điểm trung bình của họ sẽ không có ý nghĩa vì họ đã tốt nghiệp rồi nên mình sẽ bỏ qua những người thiếu 1 trong 4 cột điểm trên</ul>

# %% [markdown]
# <ul><ul><b>Tính điểm tốt nghiệp</b></ul></ul>

# %% [markdown]
# <ul><ul><ul>Tính điểm tốt nghiệp theo công thức trung bình 4 môn (Toán, Ngữ văn, Ngoại ngữ) và lấy điểm cao nhất trong 2 tổ hợp KHTN và KHXH. Tính theo cách này sẽ có những thí sinh có điểm tốt nghiệp mang giá trị NaN (thí sinh tự do), mà mình chỉ xét thí sinh thi tốt nghiệp nên xóa các dòng điểm này</ul></ul></ul>

# %%
diem_theo_khtn=(diem2022_df['Toán']+diem2022_df['Ngữ văn'] + diem2022_df['Ngoại ngữ'] + diem2022_df['KHTN'])/4
diem_theo_khxh=(diem2022_df['Toán']+diem2022_df['Ngữ văn'] + diem2022_df['Ngoại ngữ'] + diem2022_df['KHXH'])/4
diem2022_df['Điểm tốt nghiệp']=pd.DataFrame({'KHTN':diem_theo_khtn,'KHXH':diem_theo_khxh}).max(axis=1)
diem2022_df.dropna(subset=['Điểm tốt nghiệp'],inplace=True)
diem2022_df
# Out:
#              SBD Tỉnh Thành  Toán  Ngữ văn  Vật lí  Hóa học  Sinh học  KHTN  \
# 0        1000001     Hà Nội   3.6     5.00     NaN      NaN       NaN   NaN
# 1        1000002     Hà Nội   8.4     6.75     NaN      NaN       NaN   NaN
# 2        1000003     Hà Nội   5.8     7.50     NaN      NaN       NaN   NaN
# 3        1000004     Hà Nội   7.4     7.50     NaN      NaN       NaN   NaN
# 4        1000005     Hà Nội   7.2     8.50     NaN      NaN       NaN   NaN
# ...          ...        ...   ...      ...     ...      ...       ...   ...
# 995436  64006584  Hậu Giang   8.4     6.75     NaN      NaN       NaN   NaN
# 995437  64006585  Hậu Giang   5.6     6.50     NaN      NaN       NaN   NaN
# 995438  64006586  Hậu Giang   5.8     6.00     NaN      NaN       NaN   NaN
# 995439  64006587  Hậu Giang   7.6     6.75     NaN      NaN       NaN   NaN
# 995440  64006588  Hậu Giang   6.6     4.50     NaN      NaN       NaN   NaN
#
# ...

# %% [markdown]
# <ul><ul><b>Tính điểm tốt nghiệp trung bình, cao nhất và thấp nhất ở các tỉnh thành </b>
#     <ul>Tính điểm trung bình, cao nhất hay thấp nhất bằng cách gom nhóm các tỉnh thành lại rồi sao đó mỗi tỉnh thành sẽ tính điểm cao nhất, trung bình hay thấp nhất của tỉnh thành đó. </ul>
#     </ul></ul>

# %%
diem2022_mean=diem2022_df.groupby('Tỉnh Thành')['Điểm tốt nghiệp'].mean()
diem2022_max=diem2022_df.groupby('Tỉnh Thành')['Điểm tốt nghiệp'].max()
diem2022_min=diem2022_df.groupby('Tỉnh Thành')['Điểm tốt nghiệp'].min()
infor_2022 = pd.DataFrame({'Điểm tốt nghiệp trung bình':diem2022_mean,'Điểm tốt nghiệp cao nhất':diem2022_max,
                           "Điểm tốt nghiệp thấp nhất": diem2022_min})
infor_2022
# Out:
#                  Điểm tốt nghiệp trung bình  Điểm tốt nghiệp cao nhất  \
# Tỉnh Thành
# An Giang                           6.415023                    9.1500
# Bà Rịa Vũng Tàu                    6.401651                    9.2675
# Bình Dương                         7.014799                    9.1825
# Bình Phước                         5.895204                    9.0550
# Bình Thuận                         6.149934                    8.9500
# ...                                     ...                       ...
# Đà Nẵng                            6.240003                    9.1675
# Đắk Lắk                            5.663215                    9.0450
# Đắk Nông                           5.522113                    8.8050
# Đồng Nai                           6.138271                    9.1000
# Đồng Tháp                          6.251646                    8.9700
#
#                  Điểm tốt nghiệp thấp nhất
# Tỉnh Thành
# An Giang                            2.5825
# ...

# %% [markdown]
# <ul><ul><b>Liệt kê 5 tỉnh có điểm trung bình cao nhất, điểm tốt nghiệp cao nhất, và điểm thấp thấp nhất </b>
#    <ul> Khi đã có dữ liệu điểm trung bình theo tỉnh trong bảng <b>infor_2022</b> thì để biết 5 tỉnh nào có điểm cao nhất và thấp nhất thì chúng ta sort dữ liệu theo yêu cầu mong muốn và lấy 5 cái đầu hoặc 5 cái cuối và trả về index: là tên các tỉnh.
#  </ul></ul></ul>

# %%
index_max = [-5,-4,-3,-2,-1] # mảng index để lấy các index max
top5_tb_max=infor_2022['Điểm tốt nghiệp trung bình'].sort_values()[index_max].index
top5_tb_min=infor_2022['Điểm tốt nghiệp trung bình'].sort_values()[0:5].index
top5_infor2022_df= pd.DataFrame({'Điểm tốt nghiệp trung bình cao nhất':top5_tb_max,
                                 'Điểm tốt nghiệp trung bình thấp nhất':top5_tb_min})
top5_infor2022_df
# Out:
#   Điểm tốt nghiệp trung bình cao nhất Điểm tốt nghiệp trung bình thấp nhất
# 0                            Nam Định                             Hà Giang
# 1                           Ninh Bình                             Cao Bằng
# 2                           Hải Phòng                             Đắk Nông
# 3                          Bình Dương                             Lai Châu
# 4                           Vĩnh Phúc                               Sơn La

# %% [markdown]
# <ul><ul><ul><u><b>Nhận xét:</u></b> điểm trung bình là sự phản ảnh từ tổ hợp nhiều môn, tuy không đánh giá được hết do có thí sinh học lệch để ôn đại học tuy nhiên cũng đánh giá sự toàn vẹn của thí sinh ở tỉnh đó, cho thấy thí sinh đó chất lượng ổn định hơn, còn điểm trung bình tốt nghiệp mà quá thấp thì cũng đánh giá là tỉnh có có vài bộ phận thí sinh có chất lượng không ổn cần xem xét lại.</ul></ul></ul>

# %% [markdown]
# <ul><ul><b>Tính điểm liệt mỗi tỉnh, quy định điểm liệt là điểm từ 1 trở xuống</b>
#     <ul>
#         Tính điểm liệt bằng cách đếm số lượng điểm bé hơn một ở mỗi môn trong 1 tỉnh, việc này khá có ý nghĩa:
# <ul>- Nhận biết yếu kém của học sinh trong tỉnh đó để cải thiện.
# </ul>
# <ul>
#     - Nhận biết tỉnh thần nào cần được chú trọng hơn về việc nâng cao giáo dục.
# </ul>
#     </ul></ul></ul>

# %%
diem_liet_toan=diem2022_df[diem2022_df['Toán'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_van=diem2022_df[diem2022_df['Ngữ văn'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_ngoaingu=diem2022_df[diem2022_df['Ngoại ngữ'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_hoa=diem2022_df[diem2022_df['Hóa học'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_sinh=diem2022_df[diem2022_df['Sinh học'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_li=diem2022_df[diem2022_df['Vật lí'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_dia=diem2022_df[diem2022_df['Địa lí'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_su=diem2022_df[diem2022_df['Lịch sử'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_cd=diem2022_df[diem2022_df['GDCD'] <=1 ]['Tỉnh Thành'].value_counts()
diem_liet_df = pd.DataFrame({"Toán học":diem_liet_toan,"Ngữ văn":diem_liet_van,"Ngoại ngữ":diem_liet_ngoaingu,
                            "Hóa học":diem_liet_hoa,"Vật lí":diem_liet_li,"Sinh học":diem_liet_sinh,
                            "Địa lí":diem_liet_dia,'Lịch sử':diem_liet_su,"GDCD":diem_liet_cd})
diem_liet_df=diem_liet_df.replace(np.nan,0)
diem_liet_df
# Out:
#                  Toán học  Ngữ văn  Ngoại ngữ  Hóa học  Vật lí  Sinh học  \
# An Giang              1.0      0.0        3.0      0.0     0.0       0.0
# Bà Rịa Vũng Tàu       0.0      0.0        1.0      1.0     1.0       1.0
# Bình Phước            2.0      0.0        5.0      1.0     0.0       4.0
# Bình Thuận            0.0      0.0        2.0      0.0     0.0       0.0
# Bình Định             1.0      1.0        4.0      0.0     0.0       0.0
# Bạc Liêu              0.0      0.0        2.0      0.0     0.0       0.0
# Bắc Giang             0.0      0.0        3.0      0.0     0.0       1.0
# Bắc Kạn               0.0      1.0        4.0      0.0     0.0       0.0
# Bắc Ninh              1.0      0.0        2.0      0.0     0.0       0.0
# Bến Tre               0.0      0.0        4.0      0.0     0.0       0.0
# Cao Bằng              2.0      0.0        8.0      0.0     0.0       0.0
# Cà Mau                2.0      0.0        3.0      1.0     0.0       0.0
# ...

# %% [markdown]
# <ul><ul><b>Liệt kê 5 tỉnh mà số lượng điểm liệt cao</b>
#     <ul><b>diemliet_df</b> là bảng số lượng điểm liệt theo môn và theo năm, giá trị là số lượng, mình không chuyển hóa về phần trăm để chúng ta dễ nhìn nhận hơn vì số lượng điểm liệt so với tổng thể quá ít và hơn hết mình nghĩ số lượng giữa các môn và giữa các tỉnh thành cũng dễ nói lên ý nghĩa của chúng. Tiếp theo để liệt kê thì với mỗi một cột trong bảng dữ liệu thì mình sort theo giá trị rồi lấy index, nghĩa là lấy cái tỉnh thành.<ul></ul></ul>

# %%
top5_liet_toan=diem_liet_df['Toán học'].sort_values()[index_max].index
top5_liet_van=diem_liet_df['Ngữ văn'].sort_values()[index_max].index
top5_liet_nn=diem_liet_df['Ngoại ngữ'].sort_values()[index_max].index
top5_liet_hoa=diem_liet_df['Hóa học'].sort_values()[index_max].index
top5_liet_li=diem_liet_df['Vật lí'].sort_values()[index_max].index
top5_liet_sinh=diem_liet_df['Sinh học'].sort_values()[index_max].index
top5_liet_dia=diem_liet_df['Địa lí'].sort_values()[index_max].index
top5_liet_su=diem_liet_df['Lịch sử'].sort_values()[index_max].index
top5_liet_cd=diem_liet_df['GDCD'].sort_values()[index_max].index
top5_diemliet_df=pd.DataFrame({'Toán':top5_liet_toan,'Ngữ văn':top5_liet_van,'Ngoại ngữ':top5_liet_nn,'Hóa học':top5_liet_hoa,
                              'Vật lí':top5_liet_li,'Sinh học':top5_liet_sinh,'Địa lí':top5_liet_dia,'Lịch sử':top5_liet_su,
                              'GDCD':top5_liet_cd})
top5_diemliet_df
# Out:
#          Toán          Ngữ văn  Ngoại ngữ          Hóa học           Vật lí  \
# 0   Quảng Nam          Đà Nẵng   Đồng Nai  Bà Rịa Vũng Tàu        Đồng Tháp
# 1      Hà Nội          Đắk Lắk    Đắk Lắk       Kiên Giang        Sóc Trăng
# 2  Quảng Ngãi  TP. Hồ Chí Minh    Nghệ An          Đắk Lắk  Bà Rịa Vũng Tàu
# 3     Nghệ An       Quảng Ninh  Thanh Hóa          Cần Thơ        Thái Bình
# 4     Đắk Lắk        Quảng Trị     Hà Nội           Hà Nội  TP. Hồ Chí Minh
#
#      Sinh học           Địa lí          Lịch sử             GDCD
# 0     Phú Yên          Phú Yên         Tây Ninh          Đà Nẵng
# 1    Hưng Yên          Nghệ An        Hậu Giang           Hà Nội
# 2      Hà Nội        Thanh Hóa  TP. Hồ Chí Minh         Hưng Yên
# 3  Bình Phước           Hà Nội          Đắk Lắk        Hải Dương
# 4   Hải Phòng  TP. Hồ Chí Minh           Hà Nội  TP. Hồ Chí Minh

# %% [markdown]
# <ul><ul>
#     <u><b>Nhận xét:</b></u>
#     <ol>Điểm liệt cơ bản không nhiều trong tỉ số thí sinh thi, tuy nhiên có một câu hỏi là liệu vì sao thí sinh đó liệt là một câu hỏi khó trả lời: có thể vì chất lượng giáo dục hay do bản thân của chính thí sinh đó, dù lí do gì chúng ta cũng nên xem xét lại về nhiều phương diện hơn</ol>
#     <ol>
#         Bảng trên đã thống kê 5 tỉnh có điểm liệt nhiều nhất ở mỗi môn, từ bảng đó chúng ta sẽ đưa phương pháp cụ thể ở mỗi tỉnh
#     </ol>
# </ul></ul>

# %% [markdown]
# <ul><b>Đã nêu hạn chế rồi, giờ thử tìm tỉnh thành có thí sinh điểm cao, với đồ án này điểm cao là trên 8</b>
# <ul><h4>Tính điểm cao theo từng môn cũng từng tỉnh</h4>
# <ul>Tính điểm theo tỉ lệ từng tỉnh: lấy số lượng thí sinh đạt trên 8.0 chia cho tổng thí sinh thi</ul>
# <ul>Ở đây có hai công đoạn chính là đếm số lượng thí sinh trên 8 và đếm theo nhóm các tỉnh thành và chia tổng thí sinh ra tỉ lệ</ul></ul></ul>

# %%
diemcao_toan=diem2022_df[diem2022_df['Toán'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Toán'].count()
diemcao_van=diem2022_df[diem2022_df['Ngữ văn'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Ngữ văn'].count()
diemcao_nn=diem2022_df[diem2022_df['Ngoại ngữ'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Ngoại ngữ'].count()
diemcao_hoa=diem2022_df[diem2022_df['Hóa học'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Hóa học'].count()
diemcao_sinh=diem2022_df[diem2022_df['Sinh học'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Sinh học'].count()
diemcao_li=diem2022_df[diem2022_df['Vật lí'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Vật lí'].count()
diemcao_dia=diem2022_df[diem2022_df['Địa lí'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Địa lí'].count()
diemcao_su=diem2022_df[diem2022_df['Lịch sử'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['Lịch sử'].count()
diemcao_cd=diem2022_df[diem2022_df['GDCD'] >=8.0 ]['Tỉnh Thành'].value_counts()/diem2022_df.groupby('Tỉnh Thành')['GDCD'].count()
diemcao_df = pd.DataFrame({"Toán học":diemcao_toan,"Ngữ văn":diemcao_van,"Ngoại ngữ":diemcao_nn,
                            "Hóa học":diemcao_hoa,"Vật lí":diemcao_li,"Sinh học":diemcao_sinh,
                            "Địa lí":diemcao_dia,'Lịch sử':diemcao_su,"GDCD":diemcao_cd})
diemcaot_df=diemcao_df.replace(np.nan,0)
diemcao_df
# Out:
#                  Toán học   Ngữ văn  Ngoại ngữ   Hóa học    Vật lí  Sinh học  \
# An Giang         0.171694  0.218968   0.073840  0.202051  0.137214  0.053528
# Bà Rịa Vũng Tàu  0.236685  0.127731   0.178101  0.146819  0.138037  0.012941
# Bình Dương       0.326234  0.228627   0.191793  0.299584  0.248864  0.054693
# Bình Phước       0.185765  0.062889   0.070763  0.175963  0.157813  0.030323
# Bình Thuận       0.160842  0.102925   0.077445  0.226439  0.170152  0.031758
# ...                   ...       ...        ...       ...       ...       ...
# Đà Nẵng          0.282514  0.083773   0.193095  0.262988  0.223974  0.039620
# Đắk Lắk          0.168723  0.086900   0.067522  0.228007  0.178418  0.032455
# Đắk Nông         0.148078  0.019775   0.034805  0.209541  0.146679  0.026750
# Đồng Nai         0.195108  0.080037   0.121408  0.196776  0.163556  0.020518
# Đồng Tháp        0.178064  0.131984   0.063158  0.215043  0.119145  0.053675
#
# ...

# %% [markdown]
# <ul><ul><b>5 tỉnh điểm cao nhất theo từng môn</b>
#     <ul>Chúng ta có bảng các tỉnh điểm cao theo từng môn rồi, giờ chúng ta sẽ tìm 5 tỉnh điểm cao nhất trong mỗi môn bằng cách sắp xếp lấy top5 của mỗi dòng.</ul></ul></ul>

# %%
top5_cao_toan=diemcao_df['Toán học'].sort_values()[index_max].index
top5_cao_van=diemcao_df['Ngữ văn'].sort_values()[index_max].index
top5_cao_nn=diemcao_df['Ngoại ngữ'].sort_values()[index_max].index
top5_cao_hoa=diemcao_df['Hóa học'].sort_values()[index_max].index
top5_cao_li=diemcao_df['Vật lí'].sort_values()[index_max].index
top5_cao_sinh=diemcao_df['Sinh học'].sort_values()[index_max].index
top5_cao_dia=diemcao_df['Địa lí'].sort_values()[index_max].index
top5_cao_su=diemcao_df['Lịch sử'].sort_values()[index_max].index
top5_cao_cd=diemcao_df['GDCD'].sort_values()[index_max].index
top5_diemcao_df=pd.DataFrame({'Toán':top5_cao_toan,'Ngữ văn':top5_cao_van,'Ngoại ngữ':top5_cao_nn,'Hóa học':top5_cao_hoa,
                              'Vật lí':top5_cao_li,'Sinh học':top5_cao_sinh,'Địa lí':top5_cao_dia,'Lịch sử':top5_cao_su,
                              'GDCD':top5_cao_cd})
top5_diemcao_df
# Out:
#         Toán    Ngữ văn        Ngoại ngữ      Hóa học     Vật lí     Sinh học  \
# 0   Bắc Ninh    Hà Tĩnh       Bình Dương      Phú Thọ   Nam Định      Phú Thọ
# 1  Ninh Bình  Ninh Bình        Hải Phòng    Ninh Bình    Hà Tĩnh      Cần Thơ
# 2  Thái Bình     Hà Nam          Đà Nẵng     Nam Định  Vĩnh Phúc       Sơn La
# 3  Vĩnh Phúc  Vĩnh Phúc           Hà Nội  Tuyên Quang  Ninh Bình      Yên Bái
# 4   Nam Định  Hải Phòng  TP. Hồ Chí Minh      Hà Tĩnh   Bắc Ninh  Tuyên Quang
#
#       Địa lí     Lịch sử        GDCD
# 0    Phú Thọ  Bình Dương   Hải Phòng
# 1  Hải Phòng   Hải Phòng    Nam Định
# 2  Ninh Bình    Nam Định   Ninh Bình
# 3   Nam Định   Ninh Bình   Vĩnh Phúc
# 4  Vĩnh Phúc   Vĩnh Phúc  Bình Dương

# %% [markdown]
# <ul><ul><ul><u><b>Nhận xét:</b></u>
#     <ol>Chúng ta có thể nhìn thấy đây là những tỉnh có những học sinh xuất sắc của cả nước theo từng môn vì vậy chúng ta có thể nhìn nhận phần chung thì chất lượng tỉnh này tốt.</ol>
#     <ul>
#         Chúng ta thấy có nhiều tỉnh có điểm cao ở nhiều môn như là Phú Thọ, Bình Dương. </ul>
# </ul></ul></ul>

# %% [markdown]
# <ul><ul><b>Tóm lại:</b> Câu 1 là chúng ta nhìn nhận được sơ lược về tình hình học tập của các thí sinh trên toàn bộ  tỉnh thành về số lượng học sinh khá giỏi và yếu, từ đó chúng ta cần ra biện pháp tăng cường củng cố tình hình đào tạo và duy trì phong độ của các tỉnh có tình hình tốt. </ul></ul>

# %% [markdown]
# ### <ul> <u>2.</u> Năm 2020 được xem là năm mà đề dễ hơn nhiều so với năm 2022, vậy thử tìm hiểu xem đề năm nào dễ hơn và dễ để tốt nghiệp hay dễ để đậu đại học </ul>

# %% [markdown]
# <ul><ul>
#     Câu hỏi này được đặt ra khi mà hiện tại có nhiều bạn thí sinh thi xong luôn đánh giá một kì thi mình đang thi thông qua một kì thi về trước, liệu cái đánh giá đó có giúp bạn nhìn nhận được chính xác sơ lược về điểm chuẩn đại học không???<br>
#     Vậy chúng ta sẽ tiến hành như thế nào đây? Việc đánh giá có hay không có một độ khó giữa các năm thì cần đem hai năm lên bàn cân mà phân tích, vậy chúng ta sẽ phân tích điểm theo vài chi tiêu chí sau:
#     <ul>Điểm thi một môn qua hai năm trong phạm vi cả nước thông qua thang điểm trung bình của môn đó</ul>
#     <ul>Tỉ lệ thí sinh tốt nghiệp giữa hai năm <ul>
# </ul></ul>

# %% [markdown]
# ### <ul><ul><b>Xét điểm thi qua từng môn giữa hai năm </b></ul></ul>

# %% [markdown]
# #### <ul><ul><ul>Thêm cột tốt nghiệp cho năm 2020 và xóa dòng cột Điểm Tốt nghiệp chưa NaN</ul></ul></ul>

# %%
temp1=(diem2020_df['Toán']+diem2020_df['Ngữ văn'] + diem2020_df['Ngoại ngữ'] + diem2020_df['KHTN'])/4
temp2=(diem2020_df['Toán']+diem2020_df['Ngữ văn'] + diem2020_df['Ngoại ngữ'] + diem2020_df['KHXH'])/4
diem2020_df['Điểm tốt nghiệp']=pd.DataFrame({'KHTN':temp1,'KHXH':temp2 }).max(axis=1)
diem2020_df.dropna(subset=['Điểm tốt nghiệp'],inplace=True)
diem2020_df
# Out:
#              SBD  Tỉnh Thành  Toán  Ngữ văn  Vật lí  Hóa học  Sinh học  KHTN  \
# 0       18014547   Bắc Giang   6.4     6.75     NaN      NaN       NaN   NaN
# 1       18014530   Bắc Giang   7.6     6.00     NaN      NaN       NaN   NaN
# 3       18014517   Bắc Giang   8.0     7.00     NaN      NaN       NaN   NaN
# 4       18014523   Bắc Giang   8.2     6.50     8.0      8.5       5.0  7.17
# 6       18014518   Bắc Giang   7.4     7.00     NaN      NaN       NaN   NaN
# ...          ...         ...   ...      ...     ...      ...       ...   ...
# 870481  17014593  Quảng Ninh   4.6     4.00     NaN      NaN       NaN   NaN
# 870482  17014597  Quảng Ninh   7.4     8.00     NaN      NaN       NaN   NaN
# 870483  17014595  Quảng Ninh   8.2     8.75     NaN      NaN       NaN   NaN
# 870484  17014598  Quảng Ninh   4.6     6.50     NaN      NaN       NaN   NaN
# 870485  60005601    Bạc Liêu   8.0     7.75     NaN      NaN       NaN   NaN
#
# ...

# %% [markdown]
# #### <ul><ul><ul> Để so sánh một cách hợp lý thì đầu tiên trong một môn sẽ đếm số điểm có trong đó rồi chia cho tổng thí sinh thi môn đó để có tỉ lệ, khi là tỉ lệ thì sự so sánh nó hơp lí hơn so với việc so sánh về số lượng . </ul></ul></ul>

# %% [markdown]
# <ul><ul><ul><u><b>Môn toán</b></u>
#     <ul>Ở đây mình có viết một hàm chính là hàm <b>PhanBoDiem</b> với đầu vào là <b>monthi</b> là môn mình cần nhìn phân bố điểm theo hai năm 2020 và 2022 và <b>fig </b> đó là kích thức biểu đồ mà mình hiển thị, và kết quả hiện thị chính là biểu đồ cột xen nhau giữa năm 2020 và 2022, được sắp xếp theo thang điểm 0-10 theo khoảng chia là chính là khả năng điểm của bài thi.</ul>
#     </ul></ul></ul>

# %%
def PhanBoDiem(monthi,fig):
    diem2020 = diem2020_df[monthi].value_counts() / diem2020_df[monthi].count()#sl điểm i/tổng sl
    diem2022 = diem2022_df[monthi].value_counts() / diem2022_df[monthi].count()
    diemcanuoc=pd.DataFrame({"2020":diem2020,"2022":diem2022})
    diemcanuoc.sort_index().plot.bar(figsize=fig,title="Điểm "+monthi+ " 2020-2022")

# %%
PhanBoDiem('Toán',(18,6))

# %% [markdown]
# #### <ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>- trong [1.4 - 3.0]: tỉ lệ điểm 2020 cao hơn 2022</ul>
#     <ul>- trong [3.0 - 8.2]: tỉ lệ điểm năm 2022 cao hơn 2020 </ul>
#     <ul>- trong [8.2 - 10]: năm 2020 cao hơn và thập chí năm 2022 không có điểm 10 nào, 2020 lại có  </ul>
#     <ul>- Điểm số chiếm tỉ trọng cao nhất năm 2020 và 2022 đều là 7.8</ul>
#     Vậy chúng ta có thể đánh giá như sau để tốt nghiệp và đậu vào một số trường cấp trung theo yêu cầu môn toán thì năm 2022 sẽ phù hợp hơn 2020 vì phổ điểm ở mức này năm 2022 cao hơn, ở mấy trường đại học cao và top thì năm 2020 sẽ có điểm cao hơn. <br>
# Vậy năm 2022 phù hợp để dễ tốt nghiệp còn năm 2020 cơ cấu điểm cao có nhiều và thí sinh sẽ khó cơ hội đậu đại học top hơn.
# </ul></ul></ul>

# %% [markdown]
# <ul><ul> <ul><u><b>Môn Ngữ văn:</b></u>
#     <ul>
#     <ul>Điểm môn Ngữ văn thì chấm tự luận nên sẽ có nhiều thang điểm vì thế sẽ nhìn nhận theo các khoảng chia cụ thể, theo cá nhân mình thì sẽ chia như sau:
#     <ul>[0.0-1.0]: điểm liệt</ul>
#     <ul>[1.0-3.0]: điểm yếu</ul>
#     <ul>[3.0-5.0]: trung bình</ul>
#     <ul>[5.0-8.0]: điểm khá</ul>
#     <ul>[8.0-9.0]: điểm giỏi</ul>
#     <ul>[9.0-10]: điểm xuất sắc</ul>
# </ul></ul></ul></ul></ul>

# %% [markdown]
# <ul><ul><ul><ul><b> Tạo bảng phân bổ tỉ lệ theo khoảng điểm như trên</b>
#     <ul>Không như các môn khác, môn Ngữ văn chấm theo hình thức tự luận nên cần xử lý lại. Thay vì để theo giá trị điểm thì mình sẽ cho vào vùng giá trị đã nói ở trên và hiển thị vẽ biểu đồ như điểm các môn khác.</ul></ul></ul></ul></ul>

# %%
def PhanBoDiemVan(temp,thisinh_thivan):
    diemliet=sum(temp[temp.index <=1.0]) /thisinh_thivan
    diemyeu=sum(temp[(temp.index <=3.0) & (temp.index >1.0)]) /thisinh_thivan
    diemtb=sum(temp[(temp.index <=5.0) & (temp.index >3.0)])/thisinh_thivan
    diemkha=sum(temp[(temp.index <=8.0) & (temp.index >5.0)])/thisinh_thivan
    diemgioi=sum(temp[(temp.index <9.0) & (temp.index >8.0)])/thisinh_thivan
    diemxs=sum(temp[temp.index >=9.0])/thisinh_thivan
    return pd.Series({'[0.0 - 1.0]':diemliet,'(1.0-3.0]':diemyeu,'(3.0-5.0]': diemtb,'(5.0-8.0]':diemkha,
                         '(8.0-9.0)':diemgioi,'[9.0-]':diemxs}) # trả về mảng có index [0.0-1.0],..,[9.0-]  
temp=diem2020_df['Ngữ văn'].value_counts() # tra ve mang so luong gia tri cua cot ngu van năm 2020
thisinh_thivan =diem2020_df['Ngữ văn'].count() # tra ve int, so luong thi sinh thi ngu van năm 2020
diemvan2020=PhanBoDiemVan(temp,thisinh_thivan)
temp=diem2022_df['Ngữ văn'].value_counts()
thisinh_thivan =diem2022_df['Ngữ văn'].count()
diemvan2022=PhanBoDiemVan(temp,thisinh_thivan)
diemvan_canuoc= pd.DataFrame({'2020':diemvan2020,'2022':diemvan2022})
diemvan_canuoc
# Out:
#                  2020      2022
# [0.0 - 1.0]  0.000160  0.000044
# (1.0-3.0]    0.009749  0.007322
# (3.0-5.0]    0.114026  0.118338
# (5.0-8.0]    0.785494  0.747000
# (8.0-9.0)    0.078712  0.100261
# [9.0-]       0.011858  0.027034

# %% [markdown]
# #### <ul><ul><ul><ul> Vẽ biểu đồ hiển thị </ul></ul></ul></ul>

# %%
diemvan_canuoc.plot.bar(figsize=(8,8),title="Điểm Ngữ văn 2020-2022")
# Out:
# <AxesSubplot:title={'center':'Điểm Ngữ văn 2020-2022'}>

# %% [markdown]
# <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>Điểm văn dưới trung bình thì năm 2022 hơn 2020, điểm từ 5-8 năm 2020 lại cao hơn năm 2022, vậy đề văn năm 2020 cũng dễ đạt điểm trên trung bình và xét tốt nghiệp ở một số trường vừa</ul>
#     <ul>Điểm trên 8 thì năm 2022 cũng nhiều hơn,  tuy nhiên số lượng thí sinh cũng không quá đông nên việc xét đại học ở trường top cũng không quá vất vả như môn toán</ul>Nhìn chung thì điểm văn năm 2022 dễ kiếm hơn năm 2020
# </ul>
#
#  </ul></ul></ul></ul>

# %% [markdown]
# #### <ul><ul><ul><u>Môn Ngoại ngữ:</u></ul></ul></ul>

# %%
PhanBoDiem('Ngoại ngữ',(18,6))

# %% [markdown]
# <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>Cơ bản điểm hai năm này thật là đều nhau, có lẽ độ khó xấp xỉ nhau</ul>
#     <ul>- trong [0.0 - 4.6]: tỉ lệ điểm năm 2022 thấp hơn 2020 </ul>
#     <ul>- trong [4.6-10.0]: tỉ lệ điểm năm 2022 nhiều hơn 2020 và hơn rất nhiều</ul>
# Vậy chúng ta có thể đánh giá độ khó môn ngoại ngữ năm 2022 dễ hơn năm 2020 </ul>
# </ul></ul></ul>

# %% [markdown]
# #### <ul><ul><ul> <u>Môn Hóa học:</u></ul></ul>

# %%
PhanBoDiem('Hóa học',(18,6))

# %% [markdown]
# <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>- trong [0.0 - 7.0] và [9.0-10.0]: tỉ lệ điểm của hai năm 2020 và 2022 có độ chênh lệch như nhau</ul>
#     <ul>- trong [7.0 - 8.0]: tỉ lệ năm 2020 lại cao hơn 2022</ul>
#     <ul>- trong [8.0 - 9.0]: tỉ lệ năm 2022 lại cao hơn 2020</ul>
#     <ul>- Điểm chiếm tỉ trọng cao năm 2020 là 7.75 và năm 2022 là 8.0 </ul>
#
# Cũng như môn toán thì năm 2022 dễ đạt điểm trên trung bình và khá hơn năm 2020, năm 2020 thì số lượng thí sinh đạt điểm giỏi cao hơn năm 2022. Hay nói cách khác đề năm 2020 dễ hơn hoặc thí sinh năm 2020 ôn đúng bài hơn.<br>
# Vậy năm 2022 phù hợp để dễ tốt nghiệp còn năm 2020 cơ cấu điểm cao có nhiều và thí sinh sẽ khó cơ hội đậu đại học top hơn.
#     </ul></ul></ul></ul>

# %% [markdown]
# #### <ul><ul><ul><u>Môn Vật lí:</u></ul></ul>

# %%
PhanBoDiem('Vật lí',(18,6))

# %% [markdown]
# #### <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>- trong [0.0 - 4.0]: tỉ lệ điểm 2020 cao hơn 2022</ul>
#     <ul>- trong [4.0 - 7.0]: tỉ lệ điểm năm 2022 cao hơn 2020</ul>
#     <ul>- trong [7.0 - 8.5]: tỉ lệ năm 2020 lại cao hơn nhiều so với 2022</ul>
#     <ul>- trong [8.5 - 10.0]: tỉ lệ năm 2022 lại cao hơn nhiều so với 2020 và năm 2022 có xuất hiện điểm 10 nhưng 2020 thì không</ul>
#     <ul>- điểm có tỉ trọng cao nhất là 8.0 ở năm 2020 và năm 2022 là 7.25</ul>
#
# Năm 2020 dễ đạt điểm trên trung bình và khá hơn năm 2022, năm 2022 thì số lượng thí sinh đạt điểm giỏi cao hơn năm 2020. Hay nói cách khác đề năm 2022 dễ hơn.<br>
# Vậy năm 2020 phù hợp để dễ tốt nghiệp còn năm 2022 cơ cấu điểm cao có nhiều và thí sinh sẽ khó cơ hội đậu đại học top hơn.
#     </ul></ul></ul></ul>

# %% [markdown]
# #### <ul><ul><ul><u>Môn Sinh học:</u></ul></ul></ul>

# %%
PhanBoDiem('Sinh học',(18,6))

# %% [markdown]
# <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>- trong [0.0 - 4.75]: tỉ lệ điểm 2022 cao hơn 2020 và cao hơn rất nhiều</ul>
#     <ul>- trong [4.75 - 10.0]: tỉ lệ điểm năm 2020 lại cao hơn rất nhiều 2022 và năm 2020 còn xuất hiện điểm 10</ul>
#     <ul>- điểm chiếm tỉ trọng cao nhất năm 2020 là [5.25-5.5](hai khoảng bằng nhau) và 2022 là 4,5
#
# Cũng như môn toán thì năm 2022 dễ đạt điểm trên trung bình và khá hơn năm 2020, năm 2020 thì số lượng thí sinh đạt điểm giỏi cao hơn năm 2022. Hay nói cách khác đề năm 2020 dễ hơn hoặc thí sinh năm 2020 ôn đúng bài hơn.<br>
# Vậy năm 2022 phù hợp để dễ tốt nghiệp còn năm 2020 cơ cấu điểm cao có nhiều và thí sinh sẽ khó cơ hội đậu đại học top hơn.
#     </ul></ul></ul></ul>

# %% [markdown]
# #### <ul><ul><ul> <u>Môn Địa lí:</u></ul></ul></ul>

# %%
PhanBoDiem('Địa lí',(18,6))

# %% [markdown]
# <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>- trong [0.0 - 3.75]: tỉ lệ điểm 2020 cao hơn 2022</ul>
#     <ul>- trong [3.75 -6.25]: tỉ lệ điểm năm 2022 cao hơn 2020</ul>
#     <ul>- trong [6.25 -8.25]: tỉ lệ điểm năm 2020 cao hơn rất nhiều 2022</ul>
#     <ul>- trong [8.25 -9.5]: tỉ lệ điểm năm 2022 cao hơn 2020</ul>
#     <ul>- trong [9.5 -10.0]: tỉ lệ điểm năm 2020 lại cao hơn 2022</ul>
#     <ul>- điểm có tỉ trọng cao nhất năm 2020 là 7.25 và năm 2022 là 7.0</ul>
#
# Môn Địa lí thì điểm có tỉ trọng thí sinh đạt được năm 2020 cao hơn năm 2022, cũng thể hiện đề năm 2020 dễ đạt được điểm giỏi hơn so với năm 2022, nên có lẽ việc dễ tốt nghiệp hơn thì có lẽ năm 2020 sẽ dễ hơn, tuy nhiên cùng nên nhìn nhận lại cơ cấu điểm năm 2022, từ 5.0 đến 6.25 thì tỉ lệ thí sinh đạt điểm này chiếm tỉ lệ cao hơn năm 2020 rất nhiều nên việc nói năm 2022 dễ đạt tốt nghiệp cũng đúng, còn năm 2020 xét về sau thì tỉ lệ điểm cao rất nhiều nên việc chọn trường đại học mong muốn khá là khó<br>
# Vậy năm 2020,2022 phù hợp để dễ tốt nghiệp và năm 2022 nếu thí sinh chọn trường top thì khá khó khăn.</ul></ul></ul></ul>

# %% [markdown]
# #### <ul><ul><ul><u>Môn Lịch sử:</u> </ul></ul></ul>

# %%
PhanBoDiem('Lịch sử',(18,6))

# %% [markdown]
# <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>- trong [0.0 - 5.5]: tỉ lệ điểm 2020 cao hơn rất nhiều 2022</ul>
#     <ul>- trong [5.5 - 10.0]: tỉ lệ điểm năm 2022 cao hơn rất nhiều 2020</ul>
#     <ul>- tỉ trọng điểm năm 2020 là 4.5 và 2022 là 7.25</ul>
#
# Năm 2020 dễ đạt điểm trên trung bình và khá hơn năm 2022, năm 2022 thì số lượng thí sinh đạt điểm giỏi cao hơn năm 2020. Hay nói cách khác đề năm 2022 dễ hơn hoặc thí sinh năm 2022 ôn đúng bài hơn.<br>
# Vậy năm 2020 phù hợp để dễ tốt nghiệp còn năm 2022 cơ cấu điểm cao có nhiều và thí sinh sẽ khó cơ hội đậu đại học top hơn.
# </ul></ul></ul>

# %% [markdown]
# #### <ul><ul><ul><u>Môn GDCD:</u></ul></ul></ul>

# %%
PhanBoDiem('GDCD',(18,6))

# %% [markdown]
# <ul><ul><ul><ul> <b>Chúng ta nhìn thử và xem xét:</b>
#     <ul>- trong [0.0 - 5.25]: tỉ lệ điểm hai năm 2020 và 2022 không có sự chênh lệch nhiều</ul>
#     <ul>- trong [5.25 - 8.5]: tỉ lệ điểm năm 2022 cao hơn năm 2020</ul>
#     <ul>- trong [8.5 - 10.0]: tỉ lệ năm 2020 lại cao 2022</ul>
#     <ul>- tỉ trọng năm 2020 là 8.75 và năm 2022 là 8.5</ul>
#
# Nhìn chung thì môn GDCD có điểm khá cao, phổ điểm giỏi năm 2020 nhiều hơn so với năm 2022 và phổ điểm khá thì năm 2022 lại nhiều hơn năm 2020.<br>
# Vậy nên năm 2020 và 2022 đều phù hợp để tốt nghiệp tuy nhiên năm 2020 cơ cấu nhiều điểm giỏi hơn và thí sinh sẽ khó có cơ hội đậu đại học top hơn.</ul></ul></ul></ul>

# %% [markdown]
# <ul><ul><u><b>Tóm lại</b></u>:
# <ul>
# Thông qua việc đánh giá điểm số giữa một môn trong hai năm thì chúng ta có thể sơ lược nhận định rằng: năm 2022 dễ kiếm điểm hơn cho các thí sinh muốn điểm cao, còn khó cho các thí sinh ở mức trung bình khá.</ul>
# <ul>Năm 2022 thì dễ phân bố tốt hơn cho việc chọn trường theo năng lực của thí sinh.</ul>
# Tóm lại thì năm 2022 dễ để đậu tốt nghiệp hơn và còn năm 2020 dễ đậu trường trung và khó đậu trường đầu.</ul></ul>

# %% [markdown]
# ## D.DỰ ĐOÁN ĐIỂM CHUẨN 2022 TĂNG HAY GIẢM VÀ NHỮNG CƠ HỘI TỪ PHỔ ĐIỂM THEO KHỐI

# %% [markdown]
# <ul>
#     <ul>
#        Để biết mình ở đâu trong một kỳ thi thì việc đầu tiên mỗi thí sinh là phải biết điểm của mình so với mặt bằng chung và phổ điểm là cách tốt nhất để đánh giá. Ngoài ra việc phân tích cơ hội nghê nghiệp từ phổ điểm cũng đánh giá thái độ các bạn học sinh đang quan tâm theo lĩnh vực gì: ví dụ nếu tỉ lệ điểm khối A trung bình năm sau cao hơn năm trước thì ắt hẳn các bạn đang quan tâm nhiều đến các lĩnh vực về kỹ thuật hơn nên các nhà đào tạo cũng như các nhà định hướng bắt lấy xu thế mà giúp các bạn tạo đam mê và gầy dựng chuyên môn, cũng như việc cải cách giáo dục theo hướng trải nghiệm thử.
#     </ul>
# </ul>

# %% [markdown]
# <ul><ul><b> Phân tích điểm theo khối thi</b>
# <ul>
#      Hiện giờ thì có rất nhiều khối thi sinh ra bởi nhiều môn, tuy nhiên việc đánh giá này chỉ dừng lại ở các khối cơ bản
# </ul></ul></ul>

# %% [markdown]
# <ul><ul><ul><b> Hàm tạo bảng thống kê theo điểm của 1 khối trong 1 năm</b>
#     <ul>Do có nhiều điểm quá nên phải chia nhỏ đề dễ đánh giá và cái chia nhỏ theo 30 khoảng</ul>
#     <b>Hàm chia khoảng</b>
#     <ul>Ở đây mình tạo khoảng chia <=, có nghĩa là <=1 là những thí sinh thi dưới hoặc bằng 1 điểm, <=2 là những thí sinh thi điểm >1 và <=2. Ban đầu thì mình cũng tính tổng của ba môn cơ bản ( được truyền vào hàm) sao đó sẽ xóa những thí sinh không thi khối đó và tạo các khoảng cho điểm thi môn đó theo dạng nói ở trên, từ đó tạo DataFrame từ hai năm 2020,2022 để hiển thị dữ liệu.
#                                                                                                                                     </ul>
# </ul></ul></ul>

# %%
def CreateSeriesTemp(d):
    a= dict()
    for i in range(0,30):
        keyname= '<='+str(i+1)
        if(i==0):
            a[keyname]=(d[(d>=i) & (d<=i+1)].count())/d.count()
        else:
            a[keyname]=(d[(d>i) & (d<=i+1)].count())/d.count()
    return pd.Series(a)  
def chiakhoang(mon1,mon2,mon3,fig):
    diem3mon2020=(diem2020_df[mon1] + diem2020_df[mon2] +diem2020_df[mon3]).copy()
    diem3mon2020.dropna(inplace=True)
    diem3mon2022=(diem2022_df[mon1] + diem2022_df[mon2] +diem2022_df[mon3]).copy()
    diem3mon2022.dropna(inplace=True)
    nam2020 =CreateSeriesTemp(diem3mon2020)
    nam2022 =CreateSeriesTemp(diem3mon2022)
    diemtheokhoi= pd.DataFrame({'2020':nam2020,'2022':nam2022})
    diemtheokhoi.plot.bar(figsize=fig,title='Điểm 3 môn: '+''+mon1+'-'+mon2+'-'+mon3 +'(2020-2022)')  
    return diemtheokhoi

# %% [markdown]
# ### Khối A

# %%
diemtheokhoi=chiakhoang('Toán','Vật lí','Hóa học',(16,6))

# %% [markdown]
# <ul><ul><ul><b><u>Nhận xét:</u></b>
# <ul>
#       Về dự đoán thì:
#             <ul>
#                 Điểm các trường có điểm chuẩn từ 14-22 sẽ tăng so với năm 2020, từ 23-29 thì các trường có xu hướng giảm.
#     </ul>
#     Về phân tích định hướng:
#     <ul>
#         Ta thấy biểu đồ năm 2022 và 2020 đều có xu hướng tập trung ở khoẳng 21-24 điểm, đây là số điểm khá sinh viên dễ đạt nhất, chúng ta có thể nghĩ rằng thí sinh đang muốn tham gia vào các ngành công nghệ kỹ thuật nên mới tham gia thi khối A nhiều đến vậy, nên chúng ta có thể tạo điều kiện cho các thế hệ sau, có thể trải nghiệm thử các ngành nghề trong khối A này hoặc tư vấn tuyển sinh đến các địa điểm có nhiều người đăng kí khối A nhất.
#     </ul>
# </ul></ul></ul></ul>

# %% [markdown]
# ### Khối A1

# %%
diemtheokhoi=chiakhoang('Toán','Vật lí','Ngoại ngữ',(16,6))

# %% [markdown]
# <ul><ul><ul><b><u>Nhận xét:</u></b>
# <ul>
#       Về dự đoán thì:
#             <ul>
#                 Điểm các trường có điểm chuẩn từ 16-22 sẽ giảm so với năm 2020, từ 23-29 thì có xu hướng tăng do số lượng thí sinh đăng kí nguyện vọng vô trường đó. Tuy nhiên nếu thí sinh đăng kí chung 1 trường và xét chung một ngành so với các thí sinh khối A thì có vẻ hơi bị thiệt vì dường như khối A1 điểm cao hơn so với khối A nên khi đăng kí chọn ngành nên xem xét về yếu tố này.
#     </ul>
#     Về phân tích định hướng:
#     <ul>
#         Biểu đồ tập trung khối A1 cũng giống khối A nhưng có vẻ điểm khối A1 hiện đang cao hơn khối A vì nhiều trường hiện nay xét rất nhiều ngành có liên quan đến A1.
#     </ul>
# </ul></ul></ul></ul>

# %% [markdown]
# ### Khối B

# %%
diemtheokhoi=chiakhoang('Toán','Hóa học','Sinh học',(16,6))

# %% [markdown]
# <ul><ul><ul><b><u>Nhận xét:</u></b>
# <ul>
#       Về dự đoán thì:
#             <ul>
#                 Điểm các trường có điểm chuẩn từ 21-24 sẽ giảm so với năm 2020, trong khoảng [22-30] điểm thì các trường có xu hướng giảm thậm chí điểm 30 năm 2022 là không hề xuất hiện.
#     </ul>
#     Về phân tích định hướng:
#     <ul>
#        Ta thấy điểm khối B không cao bằng các khối A hay A1, trong ngành Dược thì có xét tuyển chung với khối A, nếu không phân chia thì khối B khó có cơ hội cạnh tranh lúc xét tuyển, tuy nhiên trong quá trình học thì khối B sẽ có lợi thế vì học môn Sinh còn khối A dường như không biết về sinh hay chỉ biết sơ nên có khó khăn trong quá trình tiếp thu kiến thức, về chuyển dịch cũng như hai khối kia luôn tăng theo năm.
#     </ul>
# </ul></ul></ul></ul>

# %% [markdown]
# ### Khối C

# %%
diemtheokhoi=chiakhoang('Ngữ văn','Lịch sử','Địa lí',(16,6))

# %% [markdown]
# <ul><ul><ul><b><u>Nhận xét:</u></b>
# <ul>
#       Về dự đoán thì:
#             <ul>
#                 Điểm khối C trong hai năm thay đổi rất nhiều, cơ cấu điểm khối C năm 2020 thấp hơn rất nhiều so với năm 2022,
#                 phổ điểm [21-23] cao hơn rất nhiều so với năm 2020 thậm chí năm 2022 còn xuất hiện điểm 10.
#     </ul>
#     Về phân tích định hướng:
#     <ul>
#        Về chuyển dịch thì điểm khối C có sự thay đổi rất lớn, phổ điểm khá và giỏi của năm 2022 nhiều hơn rất nhiều so với năm 2020, khả năng đầu vào của các trường xét tuyển khối C sẽ cao hơn nhiều so với năm 2020.
#     </ul>
# </ul></ul></ul></ul>

# %% [markdown]
# ### Khối D

# %%
diemtheokhoi=chiakhoang('Toán','Ngữ văn','Ngoại ngữ',(16,6))

# %% [markdown]
# <ul><ul><ul><b><u>Nhận xét:</u></b>
# <ul>
#       Về dự đoán thì:
#             <ul>
#                 Điểm khối D cơ bản thấp hơn các khối khác, điểm từ 16-21 giảm so với năm 2020, điểm từ 22-27 tăng rất nhiều.
#     </ul>
#     Về phân tích định hướng:
#     <ul>
#       Khối D cơ bản chuyển dịch theo hướng nâng cao điểm so với năm 2020, chủ yếu tập trung ở khoảng 18-22 là nhiều, ngành nghề khối D đa dạng hơn khối C, thiên về hướng xã hội và thiên về cảm xúc và giao tiếp, thường những người khối D chủ yếu là người hoạt động về lĩnh vực xã hội là nhiều nên việc trải nghiệm chính là việc tham gia các câu lạc bộ hay hoạt động thiện nguyện ở lớp, trường.
#     </ul>
# </ul></ul></ul></ul>

# %% [markdown]
# <ul><h3>Nhờ việc dự đoán điểm chuẩn, chúng ta có thể đánh giá sơ lược về tình hình điểm số của 4 khối cơ bản qua đó có thể có lựa chọn tốt nhất nguyện vọng đại học cũng như có nhìn nhận sơ lược về xu thế chọn khối thi của thí sinh.</h3></ul>

# %% [markdown]
# ## E. NGUỒN KHAM KHẢO

# %% [markdown]
# <ul>Kham khảo chính từ thư viện pandas,numpy và tài liệu học môn Nhập môn khoa học dữ liệu tại trường PTIT.</ul>

# %% [markdown]
# ## F. KẾT LUẬN

# %% [markdown]
# <ul>Thời gian không cho phép cũng như kiến thưc hạn hẹp nên dừng tại đây, nếu còn thời gian sẽ mở rộng về việc dự đoán điểm thi cũng như phân tích tỉ lệ chọn khối thi của mỗi tỉnh và đưa ra đánh giá phù hợp cho mỗi tỉnh thành như là tỉnh du lịch thì nên mạnh về khối C hay khối A1 để thúc đẩy du lịch cũng như tăng mối quan hệ với các khác du lịch nước ngoài. Mong muốn là có thể lấy dữ liệu một cách đầy đủ hơn và muốn xử lí 1 file nhỏ hơn tuy nhiên phải có tỉ lệ đúng hay sai của từng thí sinh thì qua đó mới đánh giá đúng đắn về năng lực của thí sinh.</ul>
